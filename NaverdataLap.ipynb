# %%
# !pip install fbprophet

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

import urllib.request
import datetime
import json
import glob
import sys
import os

from fbprophet import Prophet

import warnings
warnings.filterwarnings(action='ignore')

# %matplotlib inline
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.grid'] = False

pd.set_option('display.max_columns', 250)
pd.set_option('display.max_rows', 250)
pd.set_option('display.width', 100)

pd.options.display.float_format = '{:.2f}'.format
# Out:
# Collecting fbprophet
#   Downloading fbprophet-0.7.1.tar.gz (64 kB)
#      ---------------------------------------- 64.0/64.0 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Cython>=0.22 in c:\users\beaki\anaconda3\lib\site-packages (from fbprophet) (0.29.32)
# Collecting cmdstanpy==0.9.5
#   Downloading cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# Collecting pystan>=2.14
#   Downloading pystan-3.6.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\beaki\anaconda3\lib\site-packages (from fbprophet) (1.21.5)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\beaki\anaconda3\lib\site-packages (from fbprophet) (1.4.4)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\beaki\anaconda3\lib\site-packages (from fbprophet) (3.5.2)
# Collecting LunarCalendar>=0.0.9
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting convertdate>=2.1.2
#   Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.9/47.9 kB ? eta 0:00:00
# Collecting holidays>=0.10.2
#   Downloading holidays-0.21.13-py3-none-any.whl (378 kB)
#      ------------------------------------- 378.2/378.2 kB 11.9 MB/s eta 0:00:00
# Collecting setuptools-git>=1.2
#   Downloading setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\beaki\anaconda3\lib\site-packages (from fbprophet) (2.8.2)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\beaki\anaconda3\lib\site-packages (from fbprophet) (4.64.1)
# Collecting pymeeus<=1,>=0.3.13
#   Downloading PyMeeus-0.5.12.tar.gz (5.8 MB)
#      ---------------------------------------- 5.8/5.8 MB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting korean-lunar-calendar
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Collecting hijri-converter
#   Downloading hijri_converter-2.2.4-py3-none-any.whl (14 kB)
# Collecting tzdata
#   Downloading tzdata-2022.7-py2.py3-none-any.whl (340 kB)
#      -------------------------------------- 340.1/340.1 kB 7.0 MB/s eta 0:00:00
# Collecting ephem>=3.7.5.3
#   Downloading ephem-4.1.4-cp39-cp39-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz in c:\users\beaki\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->fbprophet) (2022.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\beaki\anaconda3\lib\site-packages (from matplotlib>=2.0.0->fbprophet) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\beaki\anaconda3\lib\site-packages (from matplotlib>=2.0.0->fbprophet) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\beaki\anaconda3\lib\site-packages (from matplotlib>=2.0.0->fbprophet) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\beaki\anaconda3\lib\site-packages (from matplotlib>=2.0.0->fbprophet) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\beaki\anaconda3\lib\site-packages (from matplotlib>=2.0.0->fbprophet) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\beaki\anaconda3\lib\site-packages (from matplotlib>=2.0.0->fbprophet) (21.3)
# Collecting aiohttp<4.0,>=3.6
#   Downloading aiohttp-3.8.4-cp39-cp39-win_amd64.whl (323 kB)
#      -------------------------------------- 323.6/323.6 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\beaki\anaconda3\lib\site-packages (from pystan>=2.14->fbprophet) (63.4.1)
# Collecting pysimdjson<6.0.0,>=5.0.2
#   Downloading pysimdjson-5.0.2-cp39-cp39-win_amd64.whl (156 kB)
#      -------------------------------------- 156.2/156.2 kB 4.7 MB/s eta 0:00:00
# Collecting clikit<0.7,>=0.6
#   Downloading clikit-0.6.2-py2.py3-none-any.whl (91 kB)
#      ---------------------------------------- 91.8/91.8 kB 5.4 MB/s eta 0:00:00
# Collecting pystan>=2.14
#   Downloading pystan-3.5.0-py3-none-any.whl (13 kB)
# Collecting pysimdjson<4.0,>=3.2
#   Downloading pysimdjson-3.2.0-cp39-cp39-win_amd64.whl (157 kB)
#      -------------------------------------- 157.5/157.5 kB 9.8 MB/s eta 0:00:00
# Collecting pystan>=2.14
#   Downloading pystan-3.4.0-py3-none-any.whl (13 kB)
#   Downloading pystan-3.3.0-py3-none-any.whl (13 kB)
#   Downloading pystan-3.2.0-py3-none-any.whl (13 kB)
#   Downloading pystan-3.1.1-py3-none-any.whl (13 kB)
#   Downloading pystan-3.1.0-py3-none-any.whl (13 kB)
#   Downloading pystan-3.0.2-py3-none-any.whl (13 kB)
#   Downloading pystan-3.0.1-py3-none-any.whl (12 kB)
#   Downloading pystan-3.0.0-py3-none-any.whl (12 kB)
#   Downloading pystan-2.19.1.1.tar.gz (16.2 MB)
#      --------------------------------------- 16.2/16.2 MB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six>=1.5 in c:\users\beaki\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->fbprophet) (1.16.0)
# Requirement already satisfied: colorama in c:\users\beaki\anaconda3\lib\site-packages (from tqdm>=4.36.1->fbprophet) (0.4.5)
# Building wheels for collected packages: fbprophet, pystan, pymeeus
#   Building wheel for fbprophet (setup.py): started
#   Building wheel for fbprophet (setup.py): finished with status 'error'
#   Running setup.py clean for fbprophet
#   Building wheel for pystan (setup.py): started
#   Building wheel for pystan (setup.py): still running...
#   Building wheel for pystan (setup.py): still running...
#   Building wheel for pystan (setup.py): still running...
#   Building wheel for pystan (setup.py): still running...
#   Building wheel for pystan (setup.py): finished with status 'done'
#   Created wheel for pystan: filename=pystan-2.19.1.1-cp39-cp39-win_amd64.whl size=28837381 sha256=446df2ab1a01df309c2b88286e04847e23bcac98cb56c1a6c5b8c5842a41d368
#   Stored in directory: c:\users\beaki\appdata\local\pip\cache\wheels\b8\36\bf\7ec7e363f796373cea3eb9ea94e83f5bbbb586d2edbf7e3417
#   Building wheel for pymeeus (setup.py): started
#   Building wheel for pymeeus (setup.py): finished with status 'done'
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=732001 sha256=f9e5d6d2a0383af75836da6a470dd22def2183d9a7dca98a57d09b0ab7f666d4
#   Stored in directory: c:\users\beaki\appdata\local\pip\cache\wheels\04\1f\e5\8dd0c661cd8d252817655dc14a84f7ae045d6616594145aa81
# Successfully built pystan pymeeus
# Failed to build fbprophet
# Installing collected packages: setuptools-git, pymeeus, korean-lunar-calendar, ephem, tzdata, pystan, hijri-converter, convertdate, LunarCalendar, holidays, cmdstanpy, fbprophet
#   Running setup.py install for fbprophet: started
#   Running setup.py install for fbprophet: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [345 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib
#   creating build\lib\fbprophet
#   creating build\lib\fbprophet\stan_model
#   --- Logging error ---
#   Traceback (most recent call last):
#     File "C:\Users\beaki\anaconda3\lib\logging\__init__.py", line 1086, in emit
#       stream.write(msg + self.terminator)
#   ValueError: underlying buffer has been detached
#   Call stack:
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 122, in <module>
#       setup(
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\__init__.py", line 87, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 973, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\cmd.py", line 319, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\command\build.py", line 24, in run
#       super().run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\command\build.py", line 132, in run
#       self.run_command(cmd_name)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\cmd.py", line 319, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 48, in run
#       build_models(target_dir)
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 36, in build_models
#       from fbprophet.models import StanBackendEnum
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 972, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\fbprophet\__init__.py", line 8, in <module>
#       from fbprophet.forecaster import Prophet
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\fbprophet\forecaster.py", line 15, in <module>
#       import pandas as pd
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\__init__.py", line 48, in <module>
#       from pandas.core.api import (
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\api.py", line 29, in <module>
#       from pandas.core.arrays import Categorical
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#       from pandas.core.arrays.base import (
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\arrays\base.py", line 68, in <module>
#       from pandas.core import (
#     File "<frozen importlib._bootstrap>", line 1058, in _handle_fromlist
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\arraylike.py", line 21, in <module>
#       from pandas.core.ops.common import unpack_zerodim_and_defer
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 972, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\ops\__init__.py", line 33, in <module>
#       from pandas.core.ops.array_ops import (  # noqa:F401
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py", line 48, in <module>
#       import pandas.core.computation.expressions as expressions
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\computation\expressions.py", line 19, in <module>
#       from pandas.core.computation.check import NUMEXPR_INSTALLED
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\computation\check.py", line 3, in <module>
#       ne = import_optional_dependency("numexpr", errors="warn")
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\compat\_optional.py", line 138, in import_optional_dependency
#       module = importlib.import_module(name)
#     File "C:\Users\beaki\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#       return _bootstrap._gcd_import(name[level:], package, level)
#     File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\numexpr\__init__.py", line 44, in <module>
#       nthreads = _init_num_threads()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\numexpr\utils.py", line 148, in _init_num_threads
#       log.info('Note: NumExpr detected %d cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.'%n_cores)
#   Message: 'Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.'
#   Arguments: ()
#   --- Logging error ---
#   Traceback (most recent call last):
#     File "C:\Users\beaki\anaconda3\lib\logging\__init__.py", line 1086, in emit
#       stream.write(msg + self.terminator)
#   ValueError: underlying buffer has been detached
#   Call stack:
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 122, in <module>
#       setup(
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\__init__.py", line 87, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 973, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\cmd.py", line 319, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\command\build.py", line 24, in run
#       super().run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\command\build.py", line 132, in run
#       self.run_command(cmd_name)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\cmd.py", line 319, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 48, in run
#       build_models(target_dir)
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 36, in build_models
#       from fbprophet.models import StanBackendEnum
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 972, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\fbprophet\__init__.py", line 8, in <module>
#       from fbprophet.forecaster import Prophet
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\fbprophet\forecaster.py", line 15, in <module>
#       import pandas as pd
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\__init__.py", line 48, in <module>
#       from pandas.core.api import (
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\api.py", line 29, in <module>
#       from pandas.core.arrays import Categorical
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#       from pandas.core.arrays.base import (
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\arrays\base.py", line 68, in <module>
#       from pandas.core import (
#     File "<frozen importlib._bootstrap>", line 1058, in _handle_fromlist
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\arraylike.py", line 21, in <module>
#       from pandas.core.ops.common import unpack_zerodim_and_defer
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 972, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\ops\__init__.py", line 33, in <module>
#       from pandas.core.ops.array_ops import (  # noqa:F401
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py", line 48, in <module>
#       import pandas.core.computation.expressions as expressions
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\computation\expressions.py", line 19, in <module>
#       from pandas.core.computation.check import NUMEXPR_INSTALLED
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\computation\check.py", line 3, in <module>
#       ne = import_optional_dependency("numexpr", errors="warn")
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\compat\_optional.py", line 138, in import_optional_dependency
#       module = importlib.import_module(name)
#     File "C:\Users\beaki\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#       return _bootstrap._gcd_import(name[level:], package, level)
#     File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\numexpr\__init__.py", line 44, in <module>
#       nthreads = _init_num_threads()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\numexpr\utils.py", line 160, in _init_num_threads
#       log.info('NumExpr defaulting to %d threads.'%n_cores)
#   Message: 'NumExpr defaulting to 8 threads.'
#   Arguments: ()
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 122, in <module>
#       setup(
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\__init__.py", line 87, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 973, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\cmd.py", line 319, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\command\build.py", line 24, in run
#       super().run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\command\build.py", line 132, in run
#       self.run_command(cmd_name)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\cmd.py", line 319, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 48, in run
#       build_models(target_dir)
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 36, in build_models
#       from fbprophet.models import StanBackendEnum
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\fbprophet\__init__.py", line 8, in <module>
#       from fbprophet.forecaster import Prophet
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\fbprophet\forecaster.py", line 17, in <module>
#       from fbprophet.make_holidays import get_holiday_names, make_holidays_df
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\fbprophet\make_holidays.py", line 14, in <module>
#       import fbprophet.hdays as hdays_part2
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\fbprophet\hdays.py", line 13, in <module>
#       from convertdate.islamic import from_gregorian, to_gregorian
#   ModuleNotFoundError: No module named 'convertdate'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for fbprophet
#   error: subprocess-exited-with-error
#
#   Running setup.py install for fbprophet did not run successfully.
#   exit code: 1
#
#   [1355 lines of output]
#   running install
#   C:\Users\beaki\anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   running build
#   running build_py
#   creating build
#   creating build\lib
#   creating build\lib\fbprophet
#   creating build\lib\fbprophet\stan_model
#   --- Logging error ---
#   Traceback (most recent call last):
#     File "C:\Users\beaki\anaconda3\lib\logging\__init__.py", line 1086, in emit
#       stream.write(msg + self.terminator)
#   ValueError: underlying buffer has been detached
#   Call stack:
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 122, in <module>
#       setup(
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\__init__.py", line 87, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 973, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\command\install.py", line 68, in run
#       return orig.install.run(self)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\command\install.py", line 692, in run
#       self.run_command('build')
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\cmd.py", line 319, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\command\build.py", line 24, in run
#       super().run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\command\build.py", line 132, in run
#       self.run_command(cmd_name)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\cmd.py", line 319, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 48, in run
#       build_models(target_dir)
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 36, in build_models
#       from fbprophet.models import StanBackendEnum
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 972, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\fbprophet\__init__.py", line 8, in <module>
#       from fbprophet.forecaster import Prophet
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\fbprophet\forecaster.py", line 15, in <module>
#       import pandas as pd
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\__init__.py", line 48, in <module>
#       from pandas.core.api import (
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\api.py", line 29, in <module>
#       from pandas.core.arrays import Categorical
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#       from pandas.core.arrays.base import (
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\arrays\base.py", line 68, in <module>
#       from pandas.core import (
#     File "<frozen importlib._bootstrap>", line 1058, in _handle_fromlist
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\arraylike.py", line 21, in <module>
#       from pandas.core.ops.common import unpack_zerodim_and_defer
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 972, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\ops\__init__.py", line 33, in <module>
#       from pandas.core.ops.array_ops import (  # noqa:F401
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py", line 48, in <module>
#       import pandas.core.computation.expressions as expressions
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\computation\expressions.py", line 19, in <module>
#       from pandas.core.computation.check import NUMEXPR_INSTALLED
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\core\computation\check.py", line 3, in <module>
#       ne = import_optional_dependency("numexpr", errors="warn")
#     File "C:\Users\beaki\anaconda3\lib\site-packages\pandas\compat\_optional.py", line 138, in import_optional_dependency
#       module = importlib.import_module(name)
#     File "C:\Users\beaki\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#       return _bootstrap._gcd_import(name[level:], package, level)
#     File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\anaconda3\lib\site-packages\numexpr\__init__.py", line 44, in <module>
#       nthreads = _init_num_threads()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\numexpr\utils.py", line 148, in _init_num_threads
#       log.info('Note: NumExpr detected %d cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.'%n_cores)
#   Message: 'Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.'
#   Arguments: ()
#   --- Logging error ---
#   Traceback (most recent call last):
#     File "C:\Users\beaki\anaconda3\lib\logging\__init__.py", line 1086, in emit
#       stream.write(msg + self.terminator)
#   ValueError: underlying buffer has been detached
#   Call stack:
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 122, in <module>
#       setup(
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\__init__.py", line 87, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 973, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\command\install.py", line 68, in run
#       return orig.install.run(self)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\command\install.py", line 692, in run
#       self.run_command('build')
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\cmd.py", line 319, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\command\build.py", line 24, in run
#       super().run()
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\command\build.py", line 132, in run
#       self.run_command(cmd_name)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\cmd.py", line 319, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "C:\Users\beaki\anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 992, in run_command
#       cmd_obj.run()
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 48, in run
#       build_models(target_dir)
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\setup.py", line 36, in build_models
#       from fbprophet.models import StanBackendEnum
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 972, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\fbprophet\__init__.py", line 8, in <module>
#       from fbprophet.forecaster import Prophet
#     File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#     File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#     File "C:\Users\beaki\AppData\Local\Temp\pip-install-x6igwfnt\fbprophet_6eabef60251f442e98b5677bf630d5a0\fbprophet\forecaster.py", line 15, in <module>
#       import pandas as pd
# ...
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(300): note: 또는       'void stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis(const stan::math::var &,const Pargs &...)'
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: '초기화 중': 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'에서 'const stan::math::var &'(으)로 변환할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: 원인: 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'에서 'const stan::math::var'(으)로 변환할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: 이 변환을 수행할 수 있는 사용 가능한 사용자 정의 변환 연산자가 없거나 연산자를 호출할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(295): note: 또는       'void stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis(const std::vector<int,std::allocator<int>> &,const Pargs &...)'
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: '초기화 중': 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'에서 'const std::vector<int,std::allocator<int>> &'(으)로 변환할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: 원인: 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'에서 'const std::vector<int,std::allocator<int>>'(으)로 변환할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: 이 변환을 수행할 수 있는 사용 가능한 사용자 정의 변환 연산자가 없거나 연산자를 호출할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(290): note: 또는       'void stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis(const std::vector<double,std::allocator<double>> &,const Pargs &...)'
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: '초기화 중': 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'에서 'const std::vector<double,std::allocator<double>> &'(으)로 변환할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: 원인: 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'에서 'const std::vector<double,std::allocator<double>>'(으)로 변환할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: 이 변환을 수행할 수 있는 사용 가능한 사용자 정의 변환 연산자가 없거나 연산자를 호출할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(281): note: 또는       'void stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis(const std::vector<stan::math::var,std::allocator<stan::math::var>> &,const Pargs &...)'
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: '초기화 중': 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'에서 'const std::vector<stan::math::var,std::allocator<stan::math::var>> &'(으)로 변환할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: 원인: 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'에서 'const std::vector<stan::math::var,std::allocator<stan::math::var>>'(으)로 변환할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: 이 변환을 수행할 수 있는 사용 가능한 사용자 정의 변환 연산자가 없거나 연산자를 호출할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(275): note: 또는       'void stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis(const Eigen::Matrix<double,R,C,0|_Rows==1&&_Cols!=1?Eigen::RowMajor:_Cols==1&&_Rows!=1?Eigen::ColMajor:Eigen::ColMajor,_Rows,_Cols> &,const Pargs &...)'
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: 'void stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis(const Eigen::Matrix<double,R,C,0|_Rows==1&&_Cols!=1?Eigen::RowMajor:_Cols==1&&_Rows!=1?Eigen::ColMajor:Eigen::ColMajor,_Rows,_Cols> &,const Pargs &...)': 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'에서 'const Eigen::Matrix<double,R,C,0|_Rows==1&&_Cols!=1?Eigen::RowMajor:_Cols==1&&_Rows!=1?Eigen::ColMajor:Eigen::ColMajor,_Rows,_Cols> &'에 대한 템플릿 인수를 추론할 수 없습니다.
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(266): note: 또는       'void stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis(const Eigen::Matrix<T1,R1,C1,0|_Rows==1&&_Cols!=1?Eigen::RowMajor:_Cols==1&&_Rows!=1?Eigen::ColMajor:Eigen::ColMajor,_Rows,_Cols> &,const Pargs &...)'
#           with
#           [
#               F=stan::math::internal::softmax_op,
#               T1=stan::math::var
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: 'void stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis(const Eigen::Matrix<T1,R1,C1,0|_Rows==1&&_Cols!=1?Eigen::RowMajor:_Cols==1&&_Rows!=1?Eigen::ColMajor:Eigen::ColMajor,_Rows,_Cols> &,const Pargs &...)': 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'에서 'const Eigen::Matrix<T1,R1,C1,0|_Rows==1&&_Cols!=1?Eigen::RowMajor:_Cols==1&&_Rows!=1?Eigen::ColMajor:Eigen::ColMajor,_Rows,_Cols> &'에 대한 템플릿 인수를 추론할 수 없습니다.
#           with
#           [
#               F=stan::math::internal::softmax_op,
#               T1=stan::math::var
#           ]
#           and
#           [
#               T1=stan::math::var
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: 인수 목록 '(const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>)'을(를) 일치시키는 동안
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): error C2665: 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars': 모든 인수 형식을 변환할 수 있는 오버로드된 함수가 없습니다.
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(347): note: 'std::vector<stan::math::var,std::allocator<stan::math::var>> stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars(const std::vector<double,std::allocator<double>> &)'일 수 있습니다.
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: 'std::vector<stan::math::var,std::allocator<stan::math::var>> stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars(const std::vector<double,std::allocator<double>> &)': 인수 1을(를) 'Eigen::VectorXd'에서 'const std::vector<double,std::allocator<double>> &'(으)로 변환할 수 없습니다.
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: 원인: 'Eigen::VectorXd'에서 'const std::vector<double,std::allocator<double>>'(으)로 변환할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: 이 변환을 수행할 수 있는 사용 가능한 사용자 정의 변환 연산자가 없거나 연산자를 호출할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(333): note: 또는       'stan::math::var stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars(const double &)'
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: 'stan::math::var stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars(const double &)': 인수 1을(를) 'Eigen::VectorXd'에서 'const double &'(으)로 변환할 수 없습니다.
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: 원인: 'Eigen::VectorXd'에서 'const double'(으)로 변환할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: 이 변환을 수행할 수 있는 사용 가능한 사용자 정의 변환 연산자가 없거나 연산자를 호출할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(373): note: 또는       'Eigen::Matrix<T1,R1,C1,0|_Rows==1&&_Cols!=1?Eigen::RowMajor:_Cols==1&&_Rows!=1?Eigen::ColMajor:Eigen::ColMajor,_Rows,_Cols> stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars(const Eigen::Matrix<double,R,C,0|_Rows==1&&_Cols!=1?Eigen::RowMajor:_Cols==1&&_Rows!=1?Eigen::ColMajor:Eigen::ColMajor,_Rows,_Cols> &)'
#           with
#           [
#               T1=stan::math::var,
#               F=stan::math::internal::softmax_op
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: 'Eigen::Matrix<T1,R1,C1,0|_Rows==1&&_Cols!=1?Eigen::RowMajor:_Cols==1&&_Rows!=1?Eigen::ColMajor:Eigen::ColMajor,_Rows,_Cols> stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars(const Eigen::Matrix<double,R,C,0|_Rows==1&&_Cols!=1?Eigen::RowMajor:_Cols==1&&_Rows!=1?Eigen::ColMajor:Eigen::ColMajor,_Rows,_Cols> &)': 'Eigen::VectorXd'에서 'const Eigen::Matrix<double,R,C,0|_Rows==1&&_Cols!=1?Eigen::RowMajor:_Cols==1&&_Rows!=1?Eigen::ColMajor:Eigen::ColMajor,_Rows,_Cols> &'에 대한 템플릿 인수를 추론할 수 없습니다.
#           with
#           [
#               T1=stan::math::var,
#               F=stan::math::internal::softmax_op
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: 인수 목록 '(Eigen::VectorXd)'을(를) 일치시키는 동안
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/fun/softmax.hpp(78): error C2440: 'return': 'void'에서 'Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'(으)로 변환할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\lib\stan_math\stan/math/rev/mat/fun/softmax.hpp(78): note: void 형식의 식을 다른 형식으로 변환할 수 없습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\src\stan/mcmc/sample.hpp(33): warning C4244: 'return': 'Eigen::EigenBase<Derived>::Index'에서 'int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#           with
#           [
#               Derived=Eigen::Matrix<double,-1,1,0,-1,1>
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\src\stan/services/util/read_dense_inv_metric.hpp(38): warning C4267: '인수': 'size_t'에서 'int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\src\stan/mcmc/windowed_adaptation.hpp(49): warning C4244: '=': 'double'에서 'unsigned int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\src\stan/mcmc/windowed_adaptation.hpp(50): warning C4244: '=': 'double'에서 'unsigned int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\src\stan/variational/print_progress.hpp(52): warning C4244: '초기화 중': 'double'에서 'int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\src\stan/variational/families/normal_fullrank.hpp(91): warning C4267: '초기화 중': 'size_t'에서 'const int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\src\stan/variational/families/normal_fullrank.hpp(105): warning C4244: '초기화 중': 'Eigen::EigenBase<Derived>::Index'에서 'const int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#           with
#           [
#               Derived=Eigen::Matrix<double,-1,1,0,-1,1>
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\src\stan/variational/families/normal_fullrank.hpp(124): warning C4244: '초기화 중': 'Eigen::EigenBase<Derived>::Index'에서 'const int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#           with
#           [
#               Derived=Eigen::Matrix<double,-1,1,0,-1,1>
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\src\stan/variational/families/normal_meanfield.hpp(48): warning C4267: '초기화 중': 'size_t'에서 'const int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\src\stan/variational/families/normal_meanfield.hpp(61): warning C4244: '초기화 중': 'Eigen::EigenBase<Derived>::Index'에서 'const int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#           with
#           [
#               Derived=Eigen::Matrix<double,-1,1,0,-1,1>
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\src\stan/variational/families/normal_meanfield.hpp(76): warning C4244: '초기화 중': 'Eigen::EigenBase<Derived>::Index'에서 'const int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#           with
#           [
#               Derived=Eigen::Matrix<double,-1,1,0,-1,1>
#           ]
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\src\stan/io/cmd_line.hpp(32): warning C4267: '초기화 중': 'size_t'에서 'int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\src\stan/lang/rethrow_located.hpp(117): warning C4267: '초기화 중': 'size_t'에서 'int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#   C:\Users\beaki\anaconda3\lib\site-packages\pystan\stan\src\stan/model/indexing/rvalue_index_size.hpp(20): warning C4267: 'return': 'size_t'에서 'int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#   C:\Users\beaki\AppData\Local\Temp\pystan_3_hqm2oq\stanfit4anon_model_f5236004a3fd5b8429270d00efcc0cf9_8522554836083766130.cpp(5224): warning C4267: '=': 'size_t'에서 'int'(으)로 변환하면서 데이터가 손실될 수 있습니다.
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2022\\BuildTools\\VC\\Tools\\MSVC\\14.34.31933\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# fbprophet
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12884\1928407678.py in <module>
#      15 import os
#      16
# ---> 17 from fbprophet import Prophet
#      18
#      19 import warnings
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
class NaverDataLabOpenAPI():
    """
    네이버 데이터랩 오픈 API 컨트롤러 클래스
    """

    def __init__(self, client_id, client_secret):
        """
        인증키 설정 및 검색어 그룹 초기화
        """
        self.client_id = client_id
        self.client_secret = client_secret
        self.keywordGroups = []
        self.url = "https://openapi.naver.com/v1/datalab/search"

# %%
  def add_keyword_groups(self, group_dict):
        """
        검색어 그룹 추가
        """

        keyword_gorup = {
            'groupName': group_dict['groupName'],
            'keywords': group_dict['keywords']
        }
        
        self.keywordGroups.append(keyword_gorup)
        print(f">>> Num of keywordGroups: {len(self.keywordGroups)}")

# %%
 def get_data(self, startDate, endDate, timeUnit, device, ages, gender):
        """
        요청 결과 반환
        """

        # Request body
        body = json.dumps({
            "startDate": startDate,
            "endDate": endDate,
            "timeUnit": timeUnit,
            "keywordGroups": self.keywordGroups,
            "device": device,
            "ages": ages,
            "gender": gender
        }, ensure_ascii=False)
        
        # Results
        request = urllib.request.Request(self.url)
        request.add_header("X-Naver-Client-Id",self.client_id)
        request.add_header("X-Naver-Client-Secret",self.client_secret)
        request.add_header("Content-Type","application/json")
        response = urllib.request.urlopen(request, data=body.encode("utf-8"))
        rescode = response.getcode()
        if(rescode==200):
            # Json Result
            result = json.loads(response.read())
            
            df = pd.DataFrame(result['results'][0]['data'])[['period']]
            for i in range(len(self.keywordGroups)):
                tmp = pd.DataFrame(result['results'][i]['data'])
                tmp = tmp.rename(columns={'ratio': result['results'][i]['title']})
                df = pd.merge(df, tmp, how='left', on=['period'])
            self.df = df.rename(columns={'period': '날짜'})
            self.df['날짜'] = pd.to_datetime(self.df['날짜'])
            
        else:
            print("Error Code:" + rescode)
            
        return self.df

# %%
def plot_daily_trend(self):
        """
        일 별 검색어 트렌드 그래프 출력
        """
        colList = self.df.columns[1:]
        n_col = len(colList)

        fig = plt.figure(figsize=(12,6))
        plt.title('일 별 검색어 트렌드', size=20, weight='bold')
        for i in range(n_col):
            sns.lineplot(x=self.df['날짜'], y=self.df[colList[i]], label=colList[i])
        plt.legend(loc='upper right')
        
        return fig

# %%
 def plot_monthly_trend(self):
        """
        월 별 검색어 트렌드 그래프 출력
        """
        df = self.df.copy()
        df_0 = df.groupby(by=[df['날짜'].dt.year, df['날짜'].dt.month]).mean().droplevel(0).reset_index().rename(columns={'날짜': '월'})
        df_1 = df.groupby(by=[df['날짜'].dt.year, df['날짜'].dt.month]).mean().droplevel(1).reset_index().rename(columns={'날짜': '년도'})

        df = pd.merge(df_1[['년도']], df_0, how='left', left_index=True, right_index=True)
        df['날짜'] = pd.to_datetime(df[['년도','월']].assign(일=1).rename(columns={"년도": "year", "월":'month','일':'day'}))
        
        colList = df.columns.drop(['날짜','년도','월'])
        n_col = len(colList)
                
        fig = plt.figure(figsize=(12,6))
        plt.title('월 별 검색어 트렌드', size=20, weight='bold')
        for i in range(n_col):
            sns.lineplot(x=df['날짜'], y=df[colList[i]], label=colList[i])
        plt.legend(loc='upper right')
        
        return fig

# %%
 def plot_pred_trend(self, days):
        """
        검색어 그룹 별 시계열 트렌드 예측 그래프 출력
        days: 예측일수
        """
        colList = self.df.columns[1:]
        n_col = len(colList)
        
        fig_list = []
        for i in range(n_col):
            
            globals()[f"df_{str(i)}"] = self.df[['날짜', f'{colList[i]}']]
            globals()[f"df_{str(i)}"] = globals()[f"df_{str(i)}"].rename(columns={'날짜': 'ds', f'{colList[i]}': 'y'})

            m = Prophet()
            m.fit(globals()[f"df_{str(i)}"])

            future = m.make_future_dataframe(periods=days)
            forecast = m.predict(future)
            forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
            
            globals()[f"fig_{str(i)}"] = m.plot(forecast, figsize=(12,6))
            plt.title(colList[i], size=20, weight='bold')
            
            fig_list.append(globals()[f"fig_{str(i)}"])
            
        return fig_list

# %%
keyword_group_set = {
    'keyword_group_1': {'groupName': "애플", 'keywords': ["애플","Apple","AAPL"]},
    'keyword_group_2': {'groupName': "아마존", 'keywords': ["아마존","Amazon","AMZN"]},
    'keyword_group_3': {'groupName': "구글", 'keywords': ["구글","Google","GOOGL"]},
    'keyword_group_4': {'groupName': "테슬라", 'keywords': ["테슬라","Tesla","TSLA"]},
    'keyword_group_5': {'groupName': "페이스북", 'keywords': ["페이스북","Facebook","FB"]}
}

# %%
# API 인증 정보 설정
client_id = "ms5CGPZn7da7grSHvD5H"
client_secret = "kCdzeO49AQ"

# 요청 파라미터 설정
startDate = "2020-01-01"
endDate = "2020-12-31"
timeUnit = 'date'
device = ''
ages = []
gender = ''

# 데이터 프레임 정의
naver = NaverDataLabOpenAPI(client_id=client_id, client_secret=client_secret)

naver.add_keyword_groups(keyword_group_set['keyword_group_1'])
naver.add_keyword_groups(keyword_group_set['keyword_group_2'])
naver.add_keyword_groups(keyword_group_set['keyword_group_3'])
naver.add_keyword_groups(keyword_group_set['keyword_group_4'])
naver.add_keyword_groups(keyword_group_set['keyword_group_5'])

df = naver.get_data(startDate, endDate, timeUnit, device, ages, gender)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12884\34470742.py in <module>
#      14 naver = NaverDataLabOpenAPI(client_id=client_id, client_secret=client_secret)
#      15
# ---> 16 naver.add_keyword_groups(keyword_group_set['keyword_group_1'])
#      17 naver.add_keyword_groups(keyword_group_set['keyword_group_2'])
#      18 naver.add_keyword_groups(keyword_group_set['keyword_group_3'])
#
# AttributeError: 'NaverDataLabOpenAPI' object has no attribute 'add_keyword_groups'

# %%
df.head()

# %%
df.tail()

# %%
fig_1 = naver.plot_daily_trend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12884\686300819.py in <module>
# ----> 1 fig_1 = naver.plot_daily_trend()
#
# NameError: name 'naver' is not defined

# %%
# !pip install mouse
# Out:
# Collecting mouse
#   Downloading mouse-0.7.1-py2.py3-none-any.whl (16 kB)
# Installing collected packages: mouse
# Successfully installed mouse-0.7.1
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pyautogui
# Out:
# Collecting pyautogui
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading PyAutoGUI-0.9.53.tar.gz (59 kB)
#      ---------------------------------------- 59.0/59.0 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pymsgbox
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting PyTweening>=1.0.1
#   Downloading pytweening-1.0.4.tar.gz (14 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyscreeze>=0.1.21
#   Downloading PyScreeze-0.1.28.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pygetwindow>=0.0.5
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting mouseinfo
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyrect
#   Downloading PyRect-0.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: pyautogui, pygetwindow, pyscreeze, PyTweening, mouseinfo, pymsgbox, pyperclip, pyrect
#   Building wheel for pyautogui (setup.py): started
#   Building wheel for pyautogui (setup.py): finished with status 'done'
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36601 sha256=8cff82b9b6ae25c2e6476ac43aea0c1cb6507ad4f935221c56cf5ad9fcc0ad26
#   Stored in directory: c:\users\beaki\appdata\local\pip\cache\wheels\d8\97\e4\d2edca92a87d3b5fbfb527264750a17b4ba297b9a7cab6e67f
#   Building wheel for pygetwindow (setup.py): started
#   Building wheel for pygetwindow (setup.py): finished with status 'done'
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11063 sha256=130e5045c4134f7ad89d32c84faa6049dbbffc670d7fe3eb6f8d638be9db5f89
#   Stored in directory: c:\users\beaki\appdata\local\pip\cache\wheels\44\ab\20\423c3a444793767e4e41f8377bc902f77bee212e68dcce85a5
#   Building wheel for pyscreeze (pyproject.toml): started
#   Building wheel for pyscreeze (pyproject.toml): finished with status 'done'
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.28-py3-none-any.whl size=13026 sha256=45b172cd9085a09462320777e7624dfed70ed214dba15c1364cf52abe7ea3f4a
#   Stored in directory: c:\users\beaki\appdata\local\pip\cache\wheels\a2\5b\86\99f1d8fac5d92de0ccb3f0d4ad15e3f4278baf75a9b0f20b93
#   Building wheel for PyTweening (setup.py): started
#   Building wheel for PyTweening (setup.py): finished with status 'done'
#   Created wheel for PyTweening: filename=pytweening-1.0.4-py3-none-any.whl size=5838 sha256=69b2d1784ffcedcff35256e239c1e5a9b487869574a8f83d8b8aff5948d1be03
#   Stored in directory: c:\users\beaki\appdata\local\pip\cache\wheels\a4\5d\d2\ba4c8f82163233ffaadcf383c1e34d7d92635d357d13e7b78d
#   Building wheel for mouseinfo (setup.py): started
#   Building wheel for mouseinfo (setup.py): finished with status 'done'
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10891 sha256=99f10d6709a9db25e8d0ae9f9931feb1aa0cd3f2cc56ab9ee67c68d835aa674a
#   Stored in directory: c:\users\beaki\appdata\local\pip\cache\wheels\61\73\b9\6fb1131ab36e650206e3aa0ad7a68907b41b32ac2d4f75f543
#   Building wheel for pymsgbox (pyproject.toml): started
#   Building wheel for pymsgbox (pyproject.toml): finished with status 'done'
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7417 sha256=d78d8bdf69d6d2b246d98ffbed7c330c60ee01b391c25d71230d713b7a955d5f
#   Stored in directory: c:\users\beaki\appdata\local\pip\cache\wheels\7f\13\8c\584c519464297d9637f9cd29fd1dcdf55e2a2cab225c76a2db
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11123 sha256=62ebc1e97da3bba89dfe5cf7cbc36f43b8a2feb1afa223487eb31c9e558bd02e
#   Stored in directory: c:\users\beaki\appdata\local\pip\cache\wheels\0c\09\9e\49e21a6840ef7955b06d47394afef0058f0378c0914e48b8b8
#   Building wheel for pyrect (setup.py): started
#   Building wheel for pyrect (setup.py): finished with status 'done'
#   Created wheel for pyrect: filename=PyRect-0.2.0-py2.py3-none-any.whl size=11179 sha256=787b3eae68973c0c925d497bc1dd26f2b7e21b294ec2f1c95ab5df2ceb5ab1fb
#   Stored in directory: c:\users\beaki\appdata\local\pip\cache\wheels\25\80\fa\27bb4a1c2e21f64ec71390489d52e57b7cc8afbe79bd595c5e
# Successfully built pyautogui pygetwindow pyscreeze PyTweening mouseinfo pymsgbox pyperclip pyrect
# Installing collected packages: PyTweening, pyscreeze, pyrect, pyperclip, pymsgbox, pygetwindow, mouseinfo, pyautogui
# Successfully installed PyTweening-1.0.4 mouseinfo-0.1.3 pyautogui-0.9.53 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.2.0 pyscreeze-0.1.28
