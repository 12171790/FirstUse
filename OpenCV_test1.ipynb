# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img_raw = cv2.imread('mandrill_colour.png')

# %%
type(img_raw)
np.ndarray

img_raw.shape
(1300, 1950, 3)
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img_raw)
